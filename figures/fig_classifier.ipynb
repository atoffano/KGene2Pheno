# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # ConvKB
# ## Emb
# ### Emb binary classif

# %%
# Train on embedding model's training test, validation on embedding model's validation set
# acc_emb_multiclassif_train = {'K Neighbors Classifier' : {}, 'Naive Bayes' : {}, 'Decision Tree Classifier' : {}, 'SVM - Linear Kernel' : {}, 'Ridge Classifier' : {}, 'Random Forest' : {}, 'Quadratic Discriminant Analysis' : {}, 'Linear Discriminant Analysis' : {}, 'Extra Trees Classifier' : {}, 'Light Gradient Boosting Machine' : {}, 'MLP Classifier' : {}}
# acc_emb_multiclassif_val = {'K Neighbors Classifier' : {}, 'Naive Bayes' : {}, 'Decision Tree Classifier' : {}, 'SVM - Linear Kernel' : {}, 'Ridge Classifier' : {}, 'Random Forest' : {}, 'Quadratic Discriminant Analysis' : {}, 'Linear Discriminant Analysis' : {}, 'Extra Trees Classifier' : {}, 'Light Gradient Boosting Machine' : {}, 'MLP Classifier' : {}}
# acc_scores_multiclassif_train  = {'K Neighbors Classifier' : {}, 'Naive Bayes' : {}, 'Decision Tree Classifier' : {}, 'SVM - Linear Kernel' : {}, 'Ridge Classifier' : {}, 'Random Forest' : {}, 'Quadratic Discriminant Analysis' : {}, 'Linear Discriminant Analysis' : {}, 'Extra Trees Classifier' : {}, 'Light Gradient Boosting Machine' : {}, 'MLP Classifier' : {}}
# acc_scores_multiclassif_val  = {'K Neighbors Classifier' : {}, 'Naive Bayes' : {}, 'Decision Tree Classifier' : {}, 'SVM - Linear Kernel' : {}, 'Ridge Classifier' : {}, 'Random Forest' : {}, 'Quadratic Discriminant Analysis' : {}, 'Linear Discriminant Analysis' : {}, 'Extra Trees Classifier' : {}, 'Light Gradient Boosting Machine' : {}, 'MLP Classifier' : {}}
acc_emb_binaryclassif_train = {'K Neighbors Classifier' : {}, 'Naive Bayes' : {}, 'Decision Tree Classifier' : {}, 'SVM - Linear Kernel' : {}, 'Ridge Classifier' : {}, 'Random Forest' : {}, 'Quadratic Discriminant Analysis' : {}, 'Linear Discriminant Analysis' : {}, 'Extra Trees Classifier' : {}, 'Light Gradient Boosting Machine' : {}, 'MLP Classifier' : {}}
acc_emb_binaryclassif_val = {'K Neighbors Classifier' : {}, 'Naive Bayes' : {}, 'Decision Tree Classifier' : {}, 'SVM - Linear Kernel' : {}, 'Ridge Classifier' : {}, 'Random Forest' : {}, 'Quadratic Discriminant Analysis' : {}, 'Linear Discriminant Analysis' : {}, 'Extra Trees Classifier' : {}, 'Light Gradient Boosting Machine' : {}, 'MLP Classifier' : {}}
# acc_scores_binaryclassif_train  = {'K Neighbors Classifier' : {}, 'Naive Bayes' : {}, 'Decision Tree Classifier' : {}, 'SVM - Linear Kernel' : {}, 'Ridge Classifier' : {}, 'Random Forest' : {}, 'Quadratic Discriminant Analysis' : {}, 'Linear Discriminant Analysis' : {}, 'Extra Trees Classifier' : {}, 'Light Gradient Boosting Machine' : {}, 'MLP Classifier' : {}}
# acc_scores_binaryclassif_val  = {'K Neighbors Classifier' : {}, 'Naive Bayes' : {}, 'Decision Tree Classifier' : {}, 'SVM - Linear Kernel' : {}, 'Ridge Classifier' : {}, 'Random Forest' : {}, 'Quadratic Discriminant Analysis' : {}, 'Linear Discriminant Analysis' : {}, 'Extra Trees Classifier' : {}, 'Light Gradient Boosting Machine' : {}, 'MLP Classifier' : {}}

# %%
 	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
Fold	 	 	 	 	 	 	 
0	0.8140	0.8956	0.7676	0.8461	0.8049	0.6279	0.6306
1	0.8200	0.8987	0.7512	0.8710	0.8067	0.6400	0.6461
2	0.8139	0.8935	0.7403	0.8681	0.7991	0.6278	0.6347
3	0.8194	0.8971	0.7632	0.8599	0.8087	0.6389	0.6430
4	0.8144	0.8917	0.7481	0.8624	0.8012	0.6287	0.6343
5	0.8107	0.8973	0.7727	0.8363	0.8032	0.6215	0.6233
6	0.8113	0.8943	0.7505	0.8545	0.7991	0.6227	0.6273
7	0.8201	0.8973	0.7647	0.8601	0.8096	0.6403	0.6443
8	0.8124	0.8943	0.7669	0.8438	0.8035	0.6249	0.6275
9	0.8123	0.8968	0.7688	0.8420	0.8038	0.6246	0.6270
# accuracy list
acc_emb_binaryclassif_train['K Neighbors Classifier']['accuracy'] =

# %%
acc_emb_binaryclassif_val['K Neighbors Classifier']['train'] =[0.7160, 0.7232, 0.7209, 0.7154, 0.7170, 0.7205, 0.7199, 0.7223, 0.7140, 0.7206]
acc_emb_binaryclassif_val['K Neighbors Classifier']['val'] = [0.6727]

acc_emb_binaryclassif_val['Naive Bayes']['train'] = [0.6875, 0.6893, 0.6816, 0.6795, 0.6805, 0.6886, 0.6864, 0.6834, 0.6863, 0.6862]
acc_emb_binaryclassif_val['Naive Bayes']['val'] = [0.6436]

acc_emb_binaryclassif_val['Decision Tree Classifier']['train'] = [0.7947, 0.7894, 0.7923, 0.7911, 0.7862, 0.7844, 0.7935, 0.7922, 0.7942, 0.7938]
acc_emb_binaryclassif_val['Decision Tree Classifier']['val'] = [0.7407]

acc_emb_binaryclassif_val['SVM - Linear Kernel']['train'] = [0.7740, 0.7710, 0.7649, 0.7715, 0.7701, 0.7668, 0.7690, 0.7728, 0.7687, 0.7680]
acc_emb_binaryclassif_val['SVM - Linear Kernel']['val'] = [0.7584]

acc_emb_binaryclassif_val['Ridge Classifier']['train'] = [0.7669, 0.7620, 0.7600, 0.7630, 0.7599, 0.7621, 0.7600, 0.7627, 0.7617, 0.7626]
acc_emb_binaryclassif_val['Ridge Classifier']['val'] = [0.7310]

acc_emb_binaryclassif_val['Random Forest']['train'] = [0.8470, 0.8425, 0.8399, 0.8472, 0.8401, 0.8414, 0.8394, 0.8444, 0.8391, 0.8406]
acc_emb_binaryclassif_val['Random Forest']['val'] = [0.8248]

acc_emb_binaryclassif_val['Quadratic Discriminant Analysis']['train'] = [0.7004, 0.7009, 0.6963, 0.6980, 0.6936, 0.6980, 0.7009, 0.6962, 0.7000, 0.6948]
acc_emb_binaryclassif_val['Quadratic Discriminant Analysis']['val'] = [0.6371]

acc_emb_binaryclassif_val['Linear Discriminant Analysis']['train'] = [0.7670, 0.7619, 0.7600, 0.7631, 0.7599, 0.7622, 0.7600, 0.7627, 0.7617, 0.7626]
acc_emb_binaryclassif_val['Linear Discriminant Analysis']['val'] = [0.7310]

acc_emb_binaryclassif_val['Extra Trees Classifier']['train'] = [0.8475, 0.8424, 0.8379, 0.8478, 0.8359, 0.8372, 0.8409, 0.8443, 0.8406, 0.8421]
acc_emb_binaryclassif_val['Extra Trees Classifier']['val'] = [0.8128]

acc_emb_binaryclassif_val['Light Gradient Boosting Machine']['train'] = [0.8400, 0.8380, 0.8366, 0.8408, 0.8387, 0.8366, 0.8381, 0.8396, 0.8338, 0.8371]
acc_emb_binaryclassif_val['Light Gradient Boosting Machine']['val'] = [0.8200]

acc_emb_binaryclassif_val['MLP Classifier']['train'] = [0.8140, 0.8200, 0.8139, 0.8194, 0.8144, 0.8107, 0.8113, 0.8201, 0.8124, 0.8123]
acc_emb_binaryclassif_val['MLP Classifier']['val'] = [0.7671]

# %%
# Create pandas DataFrame with the data
data = {
    'model_type': [],
    'accuracy': []
}
for model_type in acc_emb_binaryclassif_val.keys():
    for accuracy in acc_emb_binaryclassif_val[model_type]['train']:
        data['model_type'].append(model_type)
        data['accuracy'].append(accuracy)
df = pd.DataFrame(data)

print(df)
# Create histogram and box plots using seaborn
fig, ax = plt.subplots(figsize=(12,6))
sns.boxplot(data=df, x='model_type', y='accuracy', ax=ax)
plt.show()
# Out:
#                  model_type  accuracy
# 0    K Neighbors Classifier    0.7160
# 1    K Neighbors Classifier    0.7232
# 2    K Neighbors Classifier    0.7209
# 3    K Neighbors Classifier    0.7154
# 4    K Neighbors Classifier    0.7170
# ..                      ...       ...
# 105          MLP Classifier    0.8107
# 106          MLP Classifier    0.8113
# 107          MLP Classifier    0.8201
# 108          MLP Classifier    0.8124
# 109          MLP Classifier    0.8123
#
# [110 rows x 2 columns]
