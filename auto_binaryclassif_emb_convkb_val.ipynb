# %%
from pycaret.classification import *
import pandas as pd
import os
import wandb

os.chdir('/home/antoine/gene_pheno_pred')
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["WANDB_API_KEY"]="4e5748d6c6f3917c78cdc38a516a1bac776faf58"
wandb.login()
wandb.init(
    project="cigap-classif",
)
# Out:
# wandb: Currently logged in as: antoine-toffano (mlb). Use `wandb login --relogin` to force relogin
# wandb version 0.15.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/home/antoine/gene_pheno_pred/wandb/run-20230425_095810-mrk4reky</code>
# Syncing run <strong><a href='https://wandb.ai/mlb/cigap-classif/runs/mrk4reky' target="_blank">silver-field-23</a></strong> to <a href='https://wandb.ai/mlb/cigap-classif' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mlb/cigap-classif' target="_blank">https://wandb.ai/mlb/cigap-classif</a>
#  View run at <a href='https://wandb.ai/mlb/cigap-classif/runs/mrk4reky' target="_blank">https://wandb.ai/mlb/cigap-classif/runs/mrk4reky</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/mlb/cigap-classif/runs/mrk4reky?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
# Load training set
train = pd.read_csv('/home/antoine/gene_pheno_pred/ConvKB_2023-04-13_16-59-47_val.csv' , header=0)
train = train.replace('no_link_known', 1)
train = train.replace(to_replace=r'^((?!no_link_known).)*$', value=0, regex=True)
train
# Out:
#                0         1         2         3         4         5         6  \
# 0       0.176603  0.144554 -0.121246  0.352947  0.161330  0.119488  0.204768
# 1       0.230500  0.027735 -0.311731 -0.056029  0.097707  0.272195  0.340572
# 2       0.195384  0.188668 -0.220960 -0.023338 -0.027151  0.020286  0.266949
# 3       0.026929  0.074788  0.035858 -0.005145 -0.042590  0.019052  0.033178
# 4       0.008397 -0.001974 -0.007151 -0.004110 -0.033697 -0.053781 -0.049135
# ...          ...       ...       ...       ...       ...       ...       ...
# 234137  0.176400  0.218860 -0.280247  0.305255  0.101689  0.111522 -0.095150
# 234138  0.064738  0.126745 -0.028705  0.136302  0.126094  0.199326  0.161574
# 234139  0.009338  0.000967  0.000705 -0.058703 -0.058091 -0.004134  0.016403
# 234140  0.044665 -0.104824 -0.071804 -0.174067 -0.122643 -0.149357 -0.144405
# 234141  0.242349  0.151124  0.027205  0.005474 -0.026168  0.246636  0.120083
#
#                7         8         9  ...        91        92        93  \
# 0      -0.100077  0.156833 -0.120513  ...  0.048977  0.036158 -0.062647
# 1       0.002959  0.306213 -0.027642  ...  0.039863  0.051089 -0.081835
# 2      -0.348298  0.268543 -0.163545  ...  0.022186 -0.007695 -0.020189
# 3       0.090141 -0.043595 -0.071027  ...  0.167388  0.088925 -0.027883
# 4       0.044767 -0.010571  0.032441  ...  0.009489  0.020247 -0.027801
# ...          ...       ...       ...  ...       ...       ...       ...
# 234137 -0.109428  0.155395 -0.027120  ...  0.036530  0.021950 -0.020570
# 234138 -0.012139  0.113478 -0.176163  ...  0.046814  0.006897 -0.067952
# 234139  0.012446 -0.016351 -0.027040  ... -0.064294  0.002646 -0.086266
# 234140  0.002902 -0.149952  0.087081  ... -0.013302  0.045505  0.034258
# 234141 -0.302775  0.147610 -0.121330  ... -0.044542 -0.051172 -0.000744
#
#               94        95        96        97        98        99  \
# 0       0.061191  0.034371  0.017874 -0.018670 -0.061726 -0.032668
# 1       0.056872  0.049417  0.033689 -0.008890 -0.049069 -0.015917
# 2      -0.036016  0.016186  0.028108 -0.007122  0.038059 -0.028528
# 3      -0.040423  0.085831  0.083911 -0.083440 -0.009200 -0.090322
# 4       0.050793  0.010482  0.012848 -0.005974 -0.019075 -0.045278
# ...          ...       ...       ...       ...       ...       ...
# 234137 -0.017535  0.031310  0.024575 -0.009150 -0.023717 -0.029366
# 234138 -0.032035 -0.598163  0.024000 -0.018999 -0.023364 -0.046112
# 234139  0.143449  0.015991 -0.137966  0.122271 -0.188965  0.189511
# 234140  0.093059  0.120011  0.007771 -0.001258 -0.075868 -0.069958
# 234141 -0.079384 -0.052637 -0.052100  0.072378  0.059714  0.014457
#
#         ground_truth
# 0                  1
# 1                  0
# 2                  1
# 3                  0
# 4                  1
# ...              ...
# 234137             1
# 234138             0
# 234139             1
# 234140             1
# 234141             1
#
# [234142 rows x 101 columns]

# %%
# Validation set
val = pd.read_csv('/home/antoine/gene_pheno_pred/ConvKB_2023-04-13_16-59-47_test.csv' , header=0)
val = val.replace('no_link_known', 1)
val = val.replace(to_replace=r'^((?!no_link_known).)*$', value=0, regex=True)
val
# Out:
#                0         1         2         3         4         5         6  \
# 0       0.143444  0.093716 -0.137825 -0.124671 -0.096162  0.134430  0.258746
# 1       0.018331  0.045232  0.001957  0.000281 -0.007401  0.909883  0.018149
# 2       0.004819  0.054722  0.001181  0.086243  0.076688  0.046515  0.041210
# 3      -0.049837 -0.037773  0.039730 -0.042049 -0.032324 -0.035344  0.037563
# 4       0.088384  0.012557 -0.111223 -0.101479 -0.090372 -0.079046 -0.071125
# ...          ...       ...       ...       ...       ...       ...       ...
# 233779  0.028791  0.064465  0.016604 -0.005840 -0.009796  0.008425  0.013725
# 233780 -0.004770 -0.048431  0.002252 -0.001596 -0.046143 -0.110508 -0.025915
# 233781  0.027764  0.056585 -0.033077 -0.022086 -0.067494 -0.015891 -0.032308
# 233782  0.078459  0.079812 -0.076346 -0.083066 -0.081467 -0.066998 -0.050276
# 233783 -0.023869  0.010277  0.009491 -0.915700 -0.007371 -0.003883 -0.011953
#
#                7         8         9  ...        91        92        93  \
# 0      -0.316311  0.063991 -0.294353  ...  0.006072 -0.018314 -0.036506
# 1      -0.002059  0.016732 -0.009270  ...  0.023204  0.026533 -0.035074
# 2      -0.023142  0.060256 -0.125768  ...  0.027227  0.041565 -0.049319
# 3      -0.021121 -0.032801 -0.031846  ...  0.033551  0.026903 -0.041563
# 4      -0.055374 -0.095753  0.117984  ... -0.012302 -0.038869 -0.055369
# ...          ...       ...       ...  ...       ...       ...       ...
# 233779 -0.001496 -0.007599 -0.075763  ... -0.004248  0.102976 -0.020468
# 233780  0.009208  0.006273  0.032961  ... -0.211187 -0.086243  0.064273
# 233781  0.012968  0.015531 -0.080184  ...  0.051418  0.101561 -0.006042
# 233782 -0.002377 -0.093573 -0.045859  ...  0.021252  0.069637 -0.038760
# 233783  0.026766 -0.006770 -0.020082  ... -0.124045 -0.091949  0.014327
#
#               94        95        96        97        98        99  \
# 0       0.058785  0.032657  0.068184 -0.035997 -0.134148  0.025432
# 1      -0.007182  0.016385  0.017070 -0.040005 -0.024660 -0.013184
# 2      -0.046994  0.046374  0.048004 -0.061171  0.001339 -0.120643
# 3       0.005378  0.066259  0.040746 -0.047484 -0.029613 -0.017699
# 4       0.045610 -0.033408  0.062304 -0.035480 -0.049748 -0.004965
# ...          ...       ...       ...       ...       ...       ...
# 233779 -0.024157 -0.978574  0.016163  0.027392 -0.110037 -0.073671
# 233780 -0.023515 -0.043269 -0.097919  0.059382  0.175372  0.076994
# 233781 -0.104236  0.101335 -0.052880  0.089030  0.016790 -0.083716
# 233782  0.034591  0.018672  0.037403 -0.031772 -0.048327 -0.011563
# 233783 -0.197542 -0.096213 -0.095607  0.134298  0.130113  0.018350
#
#         ground_truth
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  1
# ...              ...
# 233779             1
# 233780             1
# 233781             1
# 233782             0
# 233783             1
#
# [233784 rows x 101 columns]

# %%
# Embeddings validation set set
embval = pd.read_csv('/home/antoine/gene_pheno_pred/ConvKB_2023-04-13_16-59-47_train.csv' , header=0)
embval = embval.replace('no_link_known', 1)
embval = embval.replace(to_replace=r'^((?!no_link_known).)*$', value=0, regex=True)
embval
# Out:
#                 0         1         2         3         4         5         6  \
# 0       -0.106307 -0.076018 -0.081182  0.028428  0.006551 -0.049328 -0.131857
# 1       -0.012138 -0.009232  0.024595 -0.021252 -0.015880 -0.047778 -0.011917
# 2       -0.052939 -0.071929  0.021859  0.011558 -0.049912 -0.007417  0.011347
# 3       -0.733260  0.043293  0.119687 -0.123384 -0.071939 -0.126068  0.032904
# 4       -0.036974 -0.005872 -0.002371 -0.035732 -0.029971 -0.052257  0.016698
# ...           ...       ...       ...       ...       ...       ...       ...
# 2364605 -0.052012 -0.050973  0.035910 -0.059969 -0.061255 -0.053517  1.033800
# 2364606 -0.059736 -0.061631  0.070624  0.048631  0.038553  0.030114 -0.824042
# 2364607  0.036065  0.071069 -0.168564  0.064844  0.088171  0.013884  0.160834
# 2364608  0.059826  0.027907  0.042077 -0.105650 -0.061793  0.070876  0.088055
# 2364609  0.044416  0.040018 -0.051139 -0.062561  0.000647  0.049335  0.051266
#
#                 7         8         9  ...        91        92        93  \
# 0       -0.037628  0.003007  0.085964  ... -0.088359 -0.011955  0.072061
# 1        0.028311 -0.034624  0.059547  ... -0.274189 -0.501134  0.305044
# 2        0.026139 -0.013402 -0.028613  ... -0.009154 -0.019550 -0.094600
# 3        0.110734 -0.096527 -0.095115  ... -0.101405  0.220706  0.192686
# 4        0.027884  0.000931  0.016802  ...  0.005399  0.063239 -0.027632
# ...           ...       ...       ...  ...       ...       ...       ...
# 2364605  0.041240 -0.052969  0.050190  ...  0.034043  0.038958 -0.019946
# 2364606  0.028283 -0.084142 -0.113815  ... -0.266709 -0.537886  0.321153
# 2364607 -0.273891  0.120310 -0.068251  ...  0.009662  0.028640 -0.053873
# 2364608 -0.013670 -0.131062  0.035856  ... -0.252920  0.035881  0.221206
# 2364609 -0.045116  0.042828 -0.066228  ...  0.032207  0.050358 -0.025129
#
#                94        95        96        97        98        99  \
# 0       -0.239798  0.282087 -0.085467  0.008205  0.139863 -0.100712
# 1        0.213702 -0.469372  0.195861 -0.185408  0.056212  0.258238
# 2        0.098562 -0.025860 -0.037455 -0.112670  0.071711  0.070507
# 3       -0.176124 -0.216842 -0.436630  0.103777 -0.110369 -0.125698
# 4       -0.001155  0.048586  0.052991  0.027887  0.004721 -0.061660
# ...           ...       ...       ...       ...       ...       ...
# 2364605 -0.008046  0.001575 -0.011575 -0.047649 -0.035770 -0.002342
# 2364606  0.181186 -0.507742  0.207627 -0.238616  0.106768  0.250761
# 2364607  0.002138  0.008572  0.031187 -0.037569 -0.022562  0.013139
# 2364608 -0.067258 -0.011880 -0.220015 -0.025483  0.051174 -0.045477
# 2364609  0.003666  0.044197  0.073098  0.011964 -0.054151 -0.093798
#
#          ground_truth
# 0                   0
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 2364605             1
# 2364606             0
# 2364607             0
# 2364608             0
# 2364609             1
#
# [2364610 rows x 101 columns]

# %%
# Experiment setup
s = setup(train, target = 'ground_truth', fold_strategy = 'stratifiedkfold', fold=10, train_size = 0.8, n_jobs=-1, system_log=True, use_gpu = True, log_experiment='wandb')
exp = ClassificationExperiment()
# Out:
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# <style type="text/css">
# #T_da97e_row8_col1, #T_da97e_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_da97e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da97e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_da97e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da97e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da97e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_da97e_row0_col1" class="data row0 col1" >1231</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_da97e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_da97e_row1_col1" class="data row1 col1" >ground_truth</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_da97e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_da97e_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_da97e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_da97e_row3_col1" class="data row3 col1" >(234142, 101)</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_da97e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_da97e_row4_col1" class="data row4 col1" >(234142, 101)</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_da97e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_da97e_row5_col1" class="data row5 col1" >(187313, 101)</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_da97e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_da97e_row6_col1" class="data row6 col1" >(46829, 101)</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_da97e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_da97e_row7_col1" class="data row7 col1" >100</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_da97e_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_da97e_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_da97e_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_da97e_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_da97e_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_da97e_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_da97e_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_da97e_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_da97e_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_da97e_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_da97e_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_da97e_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_da97e_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_da97e_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_da97e_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_da97e_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_da97e_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_da97e_row16_col1" class="data row16 col1" >WandbLogger</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_da97e_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_da97e_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_da97e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_da97e_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_da97e_row18_col1" class="data row18 col1" >eadf</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1

# %% [markdown]
# # K Neighbors Classifier

# %%
knn = create_model('knn')
# Out:
# <style type="text/css">
# #T_9fe67_row10_col0, #T_9fe67_row10_col1, #T_9fe67_row10_col2, #T_9fe67_row10_col3, #T_9fe67_row10_col4, #T_9fe67_row10_col5, #T_9fe67_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9fe67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fe67_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9fe67_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9fe67_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9fe67_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9fe67_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9fe67_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9fe67_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fe67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9fe67_row0_col0" class="data row0 col0" >0.7197</td>
#       <td id="T_9fe67_row0_col1" class="data row0 col1" >0.7972</td>
#       <td id="T_9fe67_row0_col2" class="data row0 col2" >0.6352</td>
#       <td id="T_9fe67_row0_col3" class="data row0 col3" >0.7644</td>
#       <td id="T_9fe67_row0_col4" class="data row0 col4" >0.6938</td>
#       <td id="T_9fe67_row0_col5" class="data row0 col5" >0.4394</td>
#       <td id="T_9fe67_row0_col6" class="data row0 col6" >0.4458</td>
#     </tr>
#     <tr>
#       <th id="T_9fe67_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9fe67_row1_col0" class="data row1 col0" >0.7156</td>
#       <td id="T_9fe67_row1_col1" class="data row1 col1" >0.7926</td>
#       <td id="T_9fe67_row1_col2" class="data row1 col2" >0.6369</td>
#       <td id="T_9fe67_row1_col3" class="data row1 col3" >0.7558</td>
#       <td id="T_9fe67_row1_col4" class="data row1 col4" >0.6913</td>
#       <td id="T_9fe67_row1_col5" class="data row1 col5" >0.4311</td>
#       <td id="T_9fe67_row1_col6" class="data row1 col6" >0.4366</td>
#     </tr>
#     <tr>
#       <th id="T_9fe67_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9fe67_row2_col0" class="data row2 col0" >0.7259</td>
#       <td id="T_9fe67_row2_col1" class="data row2 col1" >0.8017</td>
#       <td id="T_9fe67_row2_col2" class="data row2 col2" >0.6461</td>
#       <td id="T_9fe67_row2_col3" class="data row2 col3" >0.7689</td>
#       <td id="T_9fe67_row2_col4" class="data row2 col4" >0.7021</td>
#       <td id="T_9fe67_row2_col5" class="data row2 col5" >0.4518</td>
#       <td id="T_9fe67_row2_col6" class="data row2 col6" >0.4577</td>
#     </tr>
#     <tr>
#       <th id="T_9fe67_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9fe67_row3_col0" class="data row3 col0" >0.7193</td>
#       <td id="T_9fe67_row3_col1" class="data row3 col1" >0.7934</td>
#       <td id="T_9fe67_row3_col2" class="data row3 col2" >0.6430</td>
#       <td id="T_9fe67_row3_col3" class="data row3 col3" >0.7588</td>
#       <td id="T_9fe67_row3_col4" class="data row3 col4" >0.6961</td>
#       <td id="T_9fe67_row3_col5" class="data row3 col5" >0.4386</td>
#       <td id="T_9fe67_row3_col6" class="data row3 col6" >0.4438</td>
#     </tr>
#     <tr>
#       <th id="T_9fe67_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9fe67_row4_col0" class="data row4 col0" >0.7164</td>
#       <td id="T_9fe67_row4_col1" class="data row4 col1" >0.7900</td>
#       <td id="T_9fe67_row4_col2" class="data row4 col2" >0.6371</td>
#       <td id="T_9fe67_row4_col3" class="data row4 col3" >0.7572</td>
#       <td id="T_9fe67_row4_col4" class="data row4 col4" >0.6920</td>
#       <td id="T_9fe67_row4_col5" class="data row4 col5" >0.4328</td>
#       <td id="T_9fe67_row4_col6" class="data row4 col6" >0.4384</td>
#     </tr>
#     <tr>
#       <th id="T_9fe67_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9fe67_row5_col0" class="data row5 col0" >0.7212</td>
#       <td id="T_9fe67_row5_col1" class="data row5 col1" >0.7933</td>
#       <td id="T_9fe67_row5_col2" class="data row5 col2" >0.6411</td>
#       <td id="T_9fe67_row5_col3" class="data row5 col3" >0.7633</td>
#       <td id="T_9fe67_row5_col4" class="data row5 col4" >0.6969</td>
#       <td id="T_9fe67_row5_col5" class="data row5 col5" >0.4423</td>
#       <td id="T_9fe67_row5_col6" class="data row5 col6" >0.4481</td>
#     </tr>
#     <tr>
#       <th id="T_9fe67_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9fe67_row6_col0" class="data row6 col0" >0.7229</td>
#       <td id="T_9fe67_row6_col1" class="data row6 col1" >0.7981</td>
#       <td id="T_9fe67_row6_col2" class="data row6 col2" >0.6401</td>
#       <td id="T_9fe67_row6_col3" class="data row6 col3" >0.7671</td>
#       <td id="T_9fe67_row6_col4" class="data row6 col4" >0.6979</td>
#       <td id="T_9fe67_row6_col5" class="data row6 col5" >0.4457</td>
#       <td id="T_9fe67_row6_col6" class="data row6 col6" >0.4520</td>
#     </tr>
#     <tr>
#       <th id="T_9fe67_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9fe67_row7_col0" class="data row7 col0" >0.7173</td>
#       <td id="T_9fe67_row7_col1" class="data row7 col1" >0.7912</td>
#       <td id="T_9fe67_row7_col2" class="data row7 col2" >0.6333</td>
#       <td id="T_9fe67_row7_col3" class="data row7 col3" >0.7611</td>
#       <td id="T_9fe67_row7_col4" class="data row7 col4" >0.6913</td>
#       <td id="T_9fe67_row7_col5" class="data row7 col5" >0.4345</td>
#       <td id="T_9fe67_row7_col6" class="data row7 col6" >0.4408</td>
#     </tr>
#     <tr>
#       <th id="T_9fe67_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9fe67_row8_col0" class="data row8 col0" >0.7189</td>
#       <td id="T_9fe67_row8_col1" class="data row8 col1" >0.7928</td>
#       <td id="T_9fe67_row8_col2" class="data row8 col2" >0.6383</td>
#       <td id="T_9fe67_row8_col3" class="data row8 col3" >0.7609</td>
#       <td id="T_9fe67_row8_col4" class="data row8 col4" >0.6942</td>
#       <td id="T_9fe67_row8_col5" class="data row8 col5" >0.4377</td>
#       <td id="T_9fe67_row8_col6" class="data row8 col6" >0.4435</td>
#     </tr>
#     <tr>
#       <th id="T_9fe67_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9fe67_row9_col0" class="data row9 col0" >0.7184</td>
#       <td id="T_9fe67_row9_col1" class="data row9 col1" >0.7961</td>
#       <td id="T_9fe67_row9_col2" class="data row9 col2" >0.6351</td>
#       <td id="T_9fe67_row9_col3" class="data row9 col3" >0.7620</td>
#       <td id="T_9fe67_row9_col4" class="data row9 col4" >0.6928</td>
#       <td id="T_9fe67_row9_col5" class="data row9 col5" >0.4368</td>
#       <td id="T_9fe67_row9_col6" class="data row9 col6" >0.4429</td>
#     </tr>
#     <tr>
#       <th id="T_9fe67_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9fe67_row10_col0" class="data row10 col0" >0.7195</td>
#       <td id="T_9fe67_row10_col1" class="data row10 col1" >0.7946</td>
#       <td id="T_9fe67_row10_col2" class="data row10 col2" >0.6386</td>
#       <td id="T_9fe67_row10_col3" class="data row10 col3" >0.7619</td>
#       <td id="T_9fe67_row10_col4" class="data row10 col4" >0.6948</td>
#       <td id="T_9fe67_row10_col5" class="data row10 col5" >0.4391</td>
#       <td id="T_9fe67_row10_col6" class="data row10 col6" >0.4450</td>
#     </tr>
#     <tr>
#       <th id="T_9fe67_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9fe67_row11_col0" class="data row11 col0" >0.0030</td>
#       <td id="T_9fe67_row11_col1" class="data row11 col1" >0.0034</td>
#       <td id="T_9fe67_row11_col2" class="data row11 col2" >0.0037</td>
#       <td id="T_9fe67_row11_col3" class="data row11 col3" >0.0039</td>
#       <td id="T_9fe67_row11_col4

# %%
plot_model(knn, plot = 'confusion_matrix')

# %%
plot_model(knn, plot = 'error')

# %%
plot_model(knn, plot = 'parameter')
# Out:
#               Parameters
# algorithm           auto
# leaf_size             30
# metric         minkowski
# metric_params       None
# n_jobs                -1
# n_neighbors            5
# p                      2
# weights          uniform

# %%
knn_val_pred = predict_model(knn, data=val)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a75fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a75fc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a75fc_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a75fc_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a75fc_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a75fc_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a75fc_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a75fc_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a75fc_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a75fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a75fc_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_a75fc_row0_col1" class="data row0 col1" >0.6721</td>
#       <td id="T_a75fc_row0_col2" class="data row0 col2" >0.7314</td>
#       <td id="T_a75fc_row0_col3" class="data row0 col3" >0.6413</td>
#       <td id="T_a75fc_row0_col4" class="data row0 col4" >0.6835</td>
#       <td id="T_a75fc_row0_col5" class="data row0 col5" >0.6617</td>
#       <td id="T_a75fc_row0_col6" class="data row0 col6" >0.3443</td>
#       <td id="T_a75fc_row0_col7" class="data row0 col7" >0.3449</td>
#     </tr>
#   </tbody>
# </table>

# %%
knn_val_pred = predict_model(knn, data=embval)

# %%
save_model(knn, 'models_classif/convkb/binaryclassif_emb_val/knn')

# %% [markdown]
# # Naive Bayes

# %%
nb = create_model('nb')

# %%
plot_model(nb, plot = 'confusion_matrix')

# %%
plot_model(nb, plot = 'error')

# %%
plot_model(nb, plot = 'parameter')

# %%
nb_val_pred = predict_model(nb, data=val)

# %%
nb_val_pred = predict_model(nb, data=embval)

# %%
save_model(nb, 'models_classif/convkb/binaryclassif_emb_val/nb')

# %% [markdown]
# # Decision Tree Classifier

# %%
dt = create_model('dt')

# %%
plot_model(dt, plot = 'confusion_matrix')

# %%
plot_model(dt, plot = 'error')

# %%
plot_model(dt, plot = 'parameter')

# %%
dt_val_pred = predict_model(dt, data=val)

# %%
dt_val_pred = predict_model(dt, data=embval)

# %%
save_model(dt, 'models_classif/convkb/binaryclassif_emb_val/dt')

# %% [markdown]
# # SVM - Linear Kernel

# %%
svm = create_model('svm')

# %%
plot_model(svm, plot = 'confusion_matrix')

# %%
plot_model(svm, plot = 'error')

# %%
plot_model(svm, plot = 'parameter')

# %%
svm_val_pred = predict_model(svm, data=val)

# %%
svm_val_pred = predict_model(svm, data=embval)

# %%
save_model(svm, 'models_classif/convkb/binaryclassif_emb_val/svm')

# %% [markdown]
# # Ridge Classifier

# %%
ridge = create_model('ridge')

# %%
plot_model(ridge, plot = 'confusion_matrix')

# %%
plot_model(ridge, plot = 'error')

# %%
plot_model(ridge, plot = 'parameter')

# %%
ridge_val_pred = predict_model(ridge, data=val)

# %%
ridge_val_pred = predict_model(ridge, data=embval)

# %%
save_model(ridge, 'models_classif/convkb/binaryclassif_emb_val/ridge')

# %% [markdown]
# # Random Forest

# %%
rf = create_model('rf')

# %%
plot_model(rf, plot = 'confusion_matrix')

# %%
plot_model(rf, plot = 'error')

# %%
plot_model(rf, plot = 'parameter')

# %%
rf_val_pred = predict_model(rf, data=val)

# %%
rf_val_pred = predict_model(rf, data=embval)

# %%
save_model(rf, 'models_classif/convkb/binaryclassif_emb_val/rf')

# %% [markdown]
# # Quadratic Discriminant Analysis

# %%
qda = create_model('qda')

# %%
plot_model(qda, plot = 'confusion_matrix')

# %%
plot_model(qda, plot = 'error')

# %%
plot_model(qda, plot = 'parameter')

# %%
qda_val_pred = predict_model(qda, data=val)

# %%
qda_val_pred = predict_model(qda, data=embval)

# %%
save_model(qda, 'models_classif/convkb/binaryclassif_emb_val/qda')

# %% [markdown]
# # Linear Discriminant Analysis

# %%
lda = create_model('lda')

# %%
plot_model(lda, plot = 'confusion_matrix')

# %%
plot_model(lda, plot = 'error')

# %%
plot_model(lda, plot = 'parameter')

# %%
lda_val_pred = predict_model(lda, data=val)

# %%
lda_val_pred = predict_model(lda, data=embval)

# %%
save_model(lda, 'models_classif/convkb/binaryclassif_emb_val/lda')

# %% [markdown]
# # Extra Trees

# %%
et = create_model('et')

# %%
plot_model(et, plot = 'confusion_matrix')

# %%
plot_model(et, plot = 'error')

# %%
plot_model(et, plot = 'parameter')

# %%
et_val_pred = predict_model(et, data=val)

# %%
et_val_pred = predict_model(et, data=embval)

# %%
save_model(et, 'models_classif/convkb/binaryclassif_emb_val/et')

# %% [markdown]
# # Light Gradient Boosting Machine

# %%
lightgbm = create_model('lightgbm')

# %%
plot_model(lightgbm, plot = 'confusion_matrix')

# %%
plot_model(lightgbm, plot = 'error')

# %%
plot_model(lightgbm, plot = 'parameter')

# %%
lgbm_val_pred = predict_model(lightgbm, data=val)

# %%
lgbm_val_pred = predict_model(lightgbm, data=embval)

# %%
save_model(lightgbm, 'models_classif/convkb/binaryclassif_emb_val/lightgbm')

# %% [markdown]
# # MLP Classifier

# %%
mlp = create_model('mlp')

# %%
plot_model(mlp, plot = 'confusion_matrix')

# %%
plot_model(mlp, plot = 'error')

# %%
plot_model(mlp, plot = 'parameter')

# %%
mlp_val_pred = predict_model(mlp, data=val)

# %%
mlp_val_pred = predict_model(mlp, data=embval)

# %%
save_model(mlp, 'models_classif/convkb/binaryclassif_emb_val/mlp')
